# %% [markdown]
# <a href="https://colab.research.google.com/github/bryanbayup/petpoint/blob/main/CreateDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random
# Definisikan percakapan umum
conversations = [
    {'Input': 'Halo', 'Output': 'Halo! Ada yang bisa saya bantu?'},
    {'Input': 'Selamat pagi', 'Output': 'Selamat pagi! Apa kabar hari ini?'},
    {'Input': 'Terima kasih', 'Output': 'Sama-sama! Senang bisa membantu.'},
    {'Input': 'Apa kabar?', 'Output': 'Saya baik, terima kasih! Bagaimana dengan Anda?'},
    {'Input': 'Selamat siang', 'Output': 'Selamat siang! Ada yang bisa saya bantu?'},
    {'Input': 'Selamat sore', 'Output': 'Selamat sore! Apa yang bisa saya lakukan untuk Anda?'},
    {'Input': 'Selamat malam', 'Output': 'Selamat malam! Semoga Anda beristirahat dengan nyenyak.'},
    {'Input': 'Hai', 'Output': 'Hai! Apa kabar?'},
    {'Input': 'Apa yang bisa kamu lakukan?', 'Output': 'Saya bisa membantu Anda mendiagnosis penyakit hewan atau berbicara dengan Anda tentang hal-hal umum.'},
    {'Input': 'Bagaimana cuaca hari ini?', 'Output': 'Maaf, saya tidak memiliki informasi tentang cuaca saat ini.'},
    {'Input': 'Siapa kamu?', 'Output': 'Saya adalah Alexa, chatbot yang siap membantu Anda.'},
    {'Input': 'Apa nama kamu?', 'Output': 'Nama saya Alexa.'},
    {'Input': 'Apakah kamu bisa membantu saya?', 'Output': 'Tentu! Saya siap membantu Anda dengan pertanyaan tentang penyakit hewan atau percakapan umum.'},
    {'Input': 'Apa tujuanmu?', 'Output': 'Tujuan saya adalah membantu Anda dengan pertanyaan tentang kesehatan hewan atau percakapan sehari-hari.'},
    {'Input': 'Terima kasih atas bantuanmu', 'Output': 'Sama-sama! Jika ada yang lain yang bisa saya bantu, jangan ragu untuk bertanya.'},
    {'Input': 'Kamu cerdas sekali', 'Output': 'Terima kasih! Saya terus belajar untuk bisa membantu Anda lebih baik.'},
    {'Input': 'Apa makanan favoritmu?', 'Output': 'Saya adalah chatbot, jadi saya tidak makan, tetapi saya di sini untuk membantu Anda!'},
    {'Input': 'Bisa cerita lelucon?', 'Output': 'Tentu! Mengapa kucing suka bermain dengan benang? Karena mereka ingin menjadi penjahit hebat!'},
    {'Input': 'Selamat ulang tahun', 'Output': 'Selamat ulang tahun! Semoga harimu menyenangkan.'},
    {'Input': 'Apa yang kamu tahu tentang kesehatan hewan?', 'Output': 'Saya memiliki informasi tentang berbagai penyakit hewan, gejala, dan penanganan pertama. Silakan tanyakan jika Anda membutuhkan bantuan.'},
]

# Tambahkan entri percakapan umum tambahan untuk mencapai 100 entri
additional_conversations = [
    {'Input': 'Bagaimana cara merawat anjing yang sakit?', 'Output': 'Pastikan anjing Anda mendapatkan istirahat yang cukup, berikan air bersih, dan segera konsultasikan dengan dokter hewan.'},
    {'Input': 'Apakah kucing bisa sembuh dari rabies?', 'Output': 'Rabies adalah penyakit yang fatal dan tidak ada obatnya. Pencegahan melalui vaksinasi sangat penting.'},
    {'Input': 'Apa gejala umum penyakit pada anjing?', 'Output': 'Beberapa gejala umum termasuk demam, muntah, diare, kelelahan, dan perubahan perilaku.'},
    {'Input': 'Bisakah kamu memberikan tips menjaga kesehatan kucing?', 'Output': 'Tentu! Pastikan kucing Anda mendapatkan vaksinasi yang tepat, diet seimbang, dan pemeriksaan rutin ke dokter hewan.'},
    {'Input': 'Apa yang harus dilakukan jika anjing saya tidak mau makan?', 'Output': 'Coba beri makanan yang lembut atau basah, pastikan tidak ada masalah kesehatan, dan konsultasikan dengan dokter hewan jika masalah berlanjut.'},
    {'Input': 'Bagaimana cara mencegah heartworm pada anjing?', 'Output': 'Vaksinasi dan pemberian obat pencegahan secara rutin sangat efektif dalam mencegah heartworm.'},
    {'Input': 'Apa saja vaksin yang perlu diberikan pada kucing?', 'Output': 'Vaksin penting untuk kucing termasuk vaksin panleukopenia, rabies, feline herpesvirus, dan calicivirus.'},
    {'Input': 'Bagaimana cara mengatasi diare pada anjing?', 'Output': 'Pastikan anjing tetap terhidrasi, beri makanan yang mudah dicerna, dan konsultasikan dengan dokter hewan jika diare berlangsung lebih dari satu hari.'},
    {'Input': 'Apakah kucing bisa sakit jantung?', 'Output': 'Ya, kucing bisa mengalami penyakit jantung seperti kardiomiopati. Gejalanya termasuk kelelahan, sesak napas, dan pembengkakan perut.'},
    {'Input': 'Bagaimana cara mengatasi batuk pada anjing?', 'Output': 'Istirahat yang cukup, berikan cairan yang cukup, dan konsultasikan dengan dokter hewan jika batuk berlangsung lama atau parah.'},
    {'Input': 'Apakah kucing membutuhkan vitamin khusus?', 'Output': 'Kucing biasanya mendapatkan vitamin yang mereka butuhkan dari makanan yang seimbang. Namun, dalam beberapa kasus, suplementasi mungkin diperlukan sesuai anjuran dokter hewan.'},
    {'Input': 'Bagaimana cara mengenali dehidrasi pada anjing?', 'Output': 'Gejala dehidrasi pada anjing meliputi mata cekung, gusi kering, penurunan elastisitas kulit, dan lemas.'},
    {'Input': 'Apa saja gejala rabies pada anjing?', 'Output': 'Gejala rabies pada anjing termasuk perubahan perilaku, agresi, kejang, dan kesulitan bernafas.'},
    {'Input': 'Bagaimana cara mencegah penyakit parasit pada kucing?', 'Output': 'Pencegahan meliputi pemberian obat anti-parasit secara rutin, menjaga kebersihan lingkungan, dan pemeriksaan rutin ke dokter hewan.'},
    {'Input': 'Apa yang harus dilakukan jika kucing saya mengalami muntah terus-menerus?', 'Output': 'Pastikan kucing tetap terhidrasi, periksa makanan yang diberikan, dan segera konsultasikan dengan dokter hewan jika muntah berlanjut.'},
    {'Input': 'Bagaimana cara merawat kucing yang terinfeksi calicivirus?', 'Output': 'Isolasi kucing yang terinfeksi, berikan makanan lunak, bersihkan luka di mulut, dan konsultasikan dengan dokter hewan untuk perawatan medis.'},
    {'Input': 'Apa saja tanda-tanda penyakit jantung pada anjing?', 'Output': 'Tanda-tanda penyakit jantung pada anjing termasuk kelelahan, sesak napas, batuk, dan pembengkakan di perut.'},
    {'Input': 'Bagaimana cara mengatasi diare pada kucing?', 'Output': 'Pastikan kucing tetap terhidrasi, beri makanan yang lembut, dan konsultasikan dengan dokter hewan jika diare berlangsung lebih dari satu hari.'},
    {'Input': 'Apa yang harus dilakukan jika anjing saya mengalami kejang?', 'Output': 'Jaga agar anjing tetap tenang, hindari mencemari mulutnya, dan segera bawa ke dokter hewan.'},
]

# Tambahkan entri tambahan hingga mencapai 100
current_count = len(conversations)
target_count = 100

while current_count < target_count:
    convo = random.choice(additional_conversations)
    # Membuat variasi kecil
    new_convo = {
        'Input': convo['Input'] + ' lagi',
        'Output': convo['Output'] + ' Apakah ada yang lain yang bisa saya bantu?'
    }
    conversations.append(new_convo)
    current_count += 1

# Pastikan ada 100 entri
conversations = conversations[:100]

# Konversi ke DataFrame
df_conversation = pd.DataFrame(conversations)

# Simpan ke CSV
df_conversation.to_csv('general_conversation.csv', index=False)

print("general_conversation.csv telah dibuat dengan", len(df_conversation), "entri.")
# Out:
# general_conversation.csv telah dibuat dengan 100 entri.

# %%
import pandas as pd
import random

# Daftar penyakit untuk anjing dan kucing
diseases = [
    {
        'Nama Penyakit': 'Panleukopenia',
        'Nama Hewan': 'Kucing',
        'Gejala': 'Demam, muntah, diare, dehidrasi',
        'Penanganan Pertama': 'Isolasi kucing yang sakit, beri air minum yang banyak, jaga kehangatan tubuhnya, dan segera ke dokter hewan jika kondisinya tidak membaik.'
    },
    {
        'Nama Penyakit': 'Rabies',
        'Nama Hewan': 'Anjing',
        'Gejala': 'Perubahan perilaku, agresi, demam',
        'Penanganan Pertama': 'Pastikan untuk tidak terkena gigitan, isolasi hewan, jangan sentuh hewan yang menunjukkan gejala rabies, segera hubungi otoritas kesehatan hewan.'
    },
]

# Tambahkan entri penyakit untuk Kucing
additional_diseases_kucing = [
    {
        'Nama Penyakit': 'Feline Herpesvirus',
        'Nama Hewan': 'Kucing',
        'Gejala': 'Bersin, mata merah, keluarnya cairan dari hidung',
        'Penanganan Pertama': 'Jaga lingkungan kucing bersih, bersihkan cairan yang keluar dari hidung atau mata, pisahkan dari kucing lain, segera konsultasi dokter hewan.'
    },
    {
        'Nama Penyakit': 'Calicivirus',
        'Nama Hewan': 'Kucing',
        'Gejala': 'Mulut luka, bersin, kesulitan makan',
        'Penanganan Pertama': 'Beri kucing makanan lunak atau cair jika sulit makan, perhatikan pernapasannya, bersihkan mulutnya dari luka, segera bawa ke dokter hewan.'
    },
]

# Tambahkan entri penyakit untuk Anjing
additional_diseases_anjing = [
    {
        'Nama Penyakit': 'Distemper',
        'Nama Hewan': 'Anjing',
        'Gejala': 'Batuk, pilek, demam tinggi, kejang',
        'Penanganan Pertama': 'Isolasi anjing, berikan kompres hangat untuk mengurangi demam, berikan cairan, dan pantau gejala pernapasan, segera bawa ke dokter hewan.'
    },
    {
        'Nama Penyakit': 'Parvovirus',
        'Nama Hewan': 'Anjing',
        'Gejala': 'Muntah, diare berdarah, lemas',
        'Penanganan Pertama': 'Jaga anjing tetap hangat, beri cairan rehidrasi jika ada, dan segera bawa ke dokter hewan untuk penanganan lebih lanjut.'
    },
]

# Gabungkan semua entri
diseases.extend(additional_diseases_kucing)
diseases.extend(additional_diseases_anjing)

# Definisikan tambahan penyakit
additional_diseases = [
    # Tambahkan entri unik untuk Kucing
    {
        'Nama Penyakit': 'Feline Leukemia Virus',
        'Nama Hewan': 'Kucing',
        'Gejala': 'Penurunan nafsu makan, kelesuan, demam',
        'Penanganan Pertama': 'Isolasi kucing yang terinfeksi, berikan perawatan suportif, konsultasi dokter hewan.'
    },
    {
        'Nama Penyakit': 'Feline Immunodeficiency Virus',
        'Nama Hewan': 'Kucing',
        'Gejala': 'Penurunan berat badan, infeksi berulang',
        'Penanganan Pertama': 'Isolasi kucing yang terinfeksi, berikan perawatan suportif, konsultasi dokter hewan.'
    },
    # Tambahkan entri unik untuk Anjing
    {
        'Nama Penyakit': 'Leptospirosis',
        'Nama Hewan': 'Anjing',
        'Gejala': 'Demam, muntah, gagal ginjal, kelesuan',
        'Penanganan Pertama': 'Pastikan anjing tidak dehidrasi dengan memberi air bersih, bawa ke tempat yang teduh, hindari aktivitas fisik, dan segera konsultasi dokter.'
    },
    {
        'Nama Penyakit': 'Heartworm',
        'Nama Hewan': 'Anjing',
        'Gejala': 'Batuk, kelelahan, kesulitan bernapas',
        'Penanganan Pertama': 'Jaga anjing tetap tenang, beri cairan, pantau gejala pernapasan, hindari aktivitas fisik yang berat, segera konsultasi dokter hewan.'
    },
]

# Tambahkan entri tambahan hingga mencapai 200
current_count = len(diseases)
target_count = 200

while current_count < target_count:
    disease = random.choice(additional_diseases)
    # Membuat variasi kecil pada gejala dan penanganan
    new_entry = disease.copy()
    new_entry['Gejala'] = disease['Gejala'] + ', tambahan gejala'
    new_entry['Penanganan Pertama'] = disease['Penanganan Pertama'] + ' Pastikan untuk konsultasi dengan dokter hewan.'
    diseases.append(new_entry)
    current_count += 1

# Konversi ke DataFrame
df_disease = pd.DataFrame(diseases)

# Simpan ke CSV
df_disease.to_csv('disease_classification.csv', index=False)

print("disease_classification.csv telah dibuat dengan", len(df_disease), "entri.")
# Out:
# disease_classification.csv telah dibuat dengan 200 entri.
